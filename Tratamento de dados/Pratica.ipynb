# %%
import pandas as pd
import statistics   as sts
import seaborn as srn

# %%
"""
Iniciando análise exploratória de dados
    Objetivo: Identificar os possíveis problemas a serem tratados na base de dados
"""

"""
Comando "dataset.columns.tolist()" importante para entendermos como as colunas estão nomeadas, exibindo caracteres ocultos se tiver
"""

dataset = pd.read_csv("movies.csv")
dataset.columns.tolist()
# Out:
# ['MOVIES',
#  'YEAR',
#  'GENRE',
#  'RATING',
#  'ONE-LINE',
#  'STARS',
#  'VOTES',
#  'RunTime',
#  'Gross']

# %%
"""Verificando Tamanho do dataset"""
print(dataset.shape)
print(dataset.size)
# Out:
# (9999, 9)
# 89991

# %%
"""Verificando o datasete em si para identificarmos o conteudo de cada coluna"""
dataset.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                           GENRE  RATING  \
# 0      \r\nAction, Horror, Thriller                 6.1
# 1  \r\nAnimation, Action, Adventure                 5.0
# 2       \r\nDrama, Horror, Thriller                 8.2
# 3  \r\nAnimation, Adventure, Comedy                 9.2
# 4         \r\nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \r\nA woman with a mysterious illness is force...
# 1  \r\nThe war for Eternia begins again in what m...
# 2  \r\nSheriff Deputy Rick Grimes wakes up from a...
# 3  \r\nAn animated series that follows the exploi...
# ...

# %%
"""
Nessa fase conseguimos identificar algumas inconsistencias de cara, 
como dados NAN e inconsistencias no registro da coluna YEAR


Vamos começar a verificação primeiramente de dados categoricos:

 'MOVIES',
 'YEAR',
 'GENRE',
 'ONE-LINE',
 'STARS',
 
"""

"""MOVIES"""
grup_mv = dataset.groupby(["MOVIES"]).size()
grup_mv
# Out:
# MOVIES
#  13 Reasons Why              10
#  1899                         8
#  3Below: Tales of Arcadia    14
#  50M2                         8
#  7Seeds                      23
#                              ..
# Ófærð                         1
# Órbita 9                      1
# Ôkami to kôshinryô            1
# Öldür Beni Sevgilim           1
# ÜberWeihnachten               1
# Length: 6817, dtype: int64

# %%
grup_mv.sort_values(ascending=False).head(50).plot.bar(color="green")
# Out:
# <Axes: xlabel='MOVIES'>

# %%
"YEAR"
grup_ye = dataset.groupby(["YEAR"]).size()
grup_ye
# Out:
# YEAR
# (1932)          2
# (1933)          1
# (1938)          1
# (1941)          1
# (1944)          1
#                ..
# (XII)           1
# (XIII)          1
# (XIV) (2017)    1
# (XLI)           1
# (XXIII)         1
# Length: 438, dtype: int64

# %%
grup_ye.sort_values(ascending=False).head(40).plot.bar(color="green")
# Out:
# <Axes: xlabel='YEAR'>

# %%
"GENRE"
grup_ge = dataset.groupby(["GENRE"]).size()
grup_ge
# Out:
# GENRE
# \r\nAction                                       36
# \r\nAction, Adventure                             5
# \r\nAction, Adventure, Biography                  4
# \r\nAction, Adventure, Comedy                   109
# \r\nAction, Adventure, Crime                     56
#                                                ...
# \r\nTalk-Show, Sport                              2
# \r\nThriller                                     65
# \r\nThriller, Mystery                             1
# \r\nWar                                           1
# \r\nWestern                                       6
# Length: 510, dtype: int64

# %%
grup_ge.sort_values(ascending=False).head(50).plot.bar(color="green")
# Out:
# <Axes: xlabel='GENRE'>
# ) missing from font(s) DejaVu Sans.\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# ) missing from font(s) DejaVu Sans.\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
'ONE-LINE'
grup_on = dataset.groupby(['ONE-LINE']).size()
grup_on
# Out:
# ONE-LINE
# \r\n"All American" star Taye Diggs will joins Drew to be chat. Plus, Iron Chef Michael Symon will teaches Drew how to be make a hydroponic indoor herb garden and then will be shares how to use ...                See full summary »\r\n    1
# \r\n"All the Freckles in the World," set in 1990s Mexico City, is the story of a young-teen boy who is trying to get the attention of the prettiest girl at his school.                                                                       1
# \r\n"An undercover detective crosses paths with familiar faces in the mafia underworld during the final years of Britain's ruling of Hong Kong."                                                                                              1
# \r\n"Beautiful World," tells of an incident of school violence which leaves a young boy on the precipice of life and death as his family seeks for justice in his stead.                                                                      1
# ...

# %%
grup_on.sort_values(ascending=False).head(5).plot.bar(color="blue")
# Out:
# <Axes: xlabel='ONE-LINE'>
# ) missing from font(s) DejaVu Sans.\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# ) missing from font(s) DejaVu Sans.\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
'STARS'
grup_st = dataset.groupby(["STARS"]).size()
grup_st
# Out:
# STARS
# \r\n                                                                                                                                                                                             456
# \r\n            \r\n    Star:\r\nAakash Gupta\r\n                                                                                                                                                  1
# \r\n            \r\n    Star:\r\nAayush Ailawadi\r\n                                                                                                                                               1
# \r\n            \r\n    Star:\r\nAdam Conover\r\n                                                                                                                                                  1
# ...

# %%
grup_st.sort_values(ascending=False).head(5).plot.bar(color="blue")
# Out:
# <Axes: xlabel='STARS'>
# ) missing from font(s) DejaVu Sans.\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# ) missing from font(s) DejaVu Sans.\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
"""
Resumo da análise exploratória das colunas de dados categoricos

    - MOVIES, Encontramos diversos títulos que se repetem, caso os demais valores sejam iguais podemos considera-los como duplicatas

    - YEAR, Encontramos varios problemas de registro e duplicidade de dados que podem ser agrupados

    - GENRE, A coluna de genero está composta por generos compostos, não sei se isso é produtivo, pois isso dificulta o agrupamento do genero predominante de cada título

    - ONE-LINE, Encontramos um agrupamento totalmente fora da curva "add plot" com mais de 1000 ocorrencias, necessário investigar

    - STARS, Econtramos um agrupamento totalmente fora da curva, aparentimente NaN vendo que não possui título, para dizer que não possui existem um caractere não identificado "[]"

Em suma aparentimente todas as colunas de dados categoricos possem algum tipo de problema. 
"""
# Out:
# '\nResumo da análise exploratória das colunas de dados categoricos\n\n    - MOVIES, Encontramos diversos títulos que se repetem, caso os demais valores sejam iguais podemos considera-los como duplicatas\n\n    - YEAR, Encontramos varios problemas de registro e duplicidade de dados que podem ser agrupados\n\n    - GENRE, A coluna de genero está composta por generos compostos, não sei se isso é produtivo, pois isso dificulta o agrupamento do genero predominante de cada título\n\n    - ONE-LINE, Encontramos um agrupamento totalmente fora da curva "add plot" com mais de 1000 ocorrencias, necessário investigar\n\n    - STARS, Econtramos um agrupamento totalmente fora da curva, aparentimente NaN vendo que não possui título, para dizer que não possui existem um caractere não identificado "[]"\n\nEm suma aparentimente todas as colunas de dados categoricos possem algum tipo de problema. \n'

# %%
"""
    Análise exploratória dos dados númericos:        
        - RATING
        - VOTES
        - RunTime
        - Gross
"""

"RATING"

dataset["RATING"].describe()
# Out:
# count    8179.000000
# mean        6.921176
# std         1.220232
# min         1.100000
# 25%         6.200000
# 50%         7.100000
# 75%         7.800000
# max         9.900000
# Name: RATING, dtype: float64

# %%
srn.boxplot(dataset["RATING"]).set_title("RATING")
# Out:
# Text(0.5, 1.0, 'RATING')

# %%
srn.histplot(dataset["RATING"]).set_title("RATING")
# Out:
# Text(0.5, 1.0, 'RATING')

# %%
"VOTES"

dataset["VOTES"].describe()
# Out:
# count     8179
# unique    4129
# top          7
# freq        35
# Name: VOTES, dtype: object

# %%
"RunTime"
dataset["RunTime"].describe()
# Out:
# count    7041.000000
# mean       68.688539
# std        47.258056
# min         1.000000
# 25%        36.000000
# 50%        60.000000
# 75%        95.000000
# max       853.000000
# Name: RunTime, dtype: float64

# %%
srn.boxplot(dataset["RunTime"]).set_title("RunTime")
# Out:
# Text(0.5, 1.0, 'RunTime')

# %%
srn.histplot(dataset["RunTime"]).set_title("RunTime")
# Out:
# Text(0.5, 1.0, 'RunTime')

# %%
"Gross"
dataset["Gross"].describe()
# Out:
# count        460
# unique       332
# top       $0.01M
# freq          22
# Name: Gross, dtype: object

# %%
"""
Relatório referenta a análise exploratória dos dados núméricos:

    - RATING, Aparentimente nada de errado, apesar do boxplot ter sinalizado alguns outliers não é nada fora do permitido, notas de 0 a 4 são permitidas e totalmente possíveis o histograma confirma o boxplot, e quanto as médias e mediana, estão bem proxiamas.

    - VOTES, Por algum motivo, não foi identificada como uma coluna númerica, precisamos identificar o que está ocorrendo de errado

    - RunTime, Aparentimente nada de errado, apesar de termos alguns pontos fora da curva, a média deu onde está a concentração maior vizualizado pelo histograma. Temos 5 outlier "absurdo", esses talvez podemos considerar remover. 

    - Gross, Por algum motivo, não foi identificada como uma coluna númerica, precisamos identificar o que está ocorrendo de errado
"""
# Out:
# '\nRelatório referenta a análise exploratória dos dados núméricos:\n\n    - RATING, Aparentimente nada de errado, apesar do boxplot ter sinalizado alguns outliers não é nada fora do permitido, notas de 0 a 4 são permitidas e totalmente possíveis o histograma confirma o boxplot, e quanto as médias e mediana, estão bem proxiamas.\n\n    - VOTES, Por algum motivo, não foi identificada como uma coluna númerica, precisamos identificar o que está ocorrendo de errado\n\n    - RunTime, Aparentimente nada de errado, apesar de termos alguns pontos fora da curva, a média deu onde está a concentração maior vizualizado pelo histograma. Temos 5 outlier "absurdo", esses talvez podemos considerar remover. \n\n    - Gross, Por algum motivo, não foi identificada como uma coluna númerica, precisamos identificar o que está ocorrendo de errado\n'

# %%
dataset.isnull().sum()
# Out:
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %%
"""Iniciando tratamento de duplicatas"""
dataset[dataset.duplicated(['MOVIES',
 'YEAR',
 'GENRE',
 'RATING',
 'ONE-LINE',
 'STARS',
 'VOTES',
 'RunTime',
 'Gross'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [MOVIES, YEAR, GENRE, RATING, ONE-LINE, STARS, VOTES, RunTime, Gross]
# Index: []

# %%
dataset.drop_duplicates(subset=
['MOVIES',
 'YEAR',
 'GENRE',
 'RATING',
 'ONE-LINE',
 'STARS',
 'VOTES',
 'RunTime',
 'Gross'],
 keep="first",inplace=True)

# %%
"""
Iniciando tratamento dos dados categoricos

"""
import re
"MOVIES"
dataset.loc[dataset["MOVIES"].str.contains("Bleach")]
# Out:
#                 MOVIES         YEAR  \
# 447    Bleach: Burîchi  (2004–2012)
# 1743   Bleach: Burîchu       (2018)
# 2558  Soaked in Bleach       (2015)
# 6536   Bleach: Burîchi  (2004–2012)
# 6555   Bleach: Burîchi  (2004–2012)
# ...                ...          ...
# 6614   Bleach: Burîchi  (2004–2012)
# 6615   Bleach: Burîchi  (2004–2012)
# 6616   Bleach: Burîchi  (2004–2012)
# 6617   Bleach: Burîchi  (2004–2012)
# 6618   Bleach: Burîchi  (2004–2012)
#
#                                              GENRE  RATING  \
# 447   \r\nAnimation, Action, Adventure                 8.1
# 1743    \r\nAction, Adventure, Fantasy                 6.4
# 2558            \r\nDocumentary, Crime                 7.4
# 6536  \r\nAnimation, Action, Adventure                 8.7
# 6555  \r\nAnimation, Action, Adventure                 7.9
# ...                                            ...     ...
# 6614  \r\nAnimation, Action, Adventure                 8.2
# ...

# %%
"""Mesmo pos processo de remoção de duplicatas coluna MOVIES continuam com grande numero de repetições, muito pelo fato de conter filmes e series juntos"""
# Out:
# 'Mesmo pos processo de remoção de duplicatas coluna MOVIES continuam com grande numero de repetições, muito pelo fato de conter filmes e series juntos'

# %%
'YEAR'
dataset["YEAR"] = dataset["YEAR"].str.replace(r"[\D^-]","",regex=True)

# %%
dataset.groupby(dataset["YEAR"]).size().sort_values(ascending=False).head(30).plot.bar(color="Green")
# Out:
# <Axes: xlabel='YEAR'>

# %%
#dataset[dataset["YEAR"].str.len()> 4].apply(lambda x: x[:-4]if pd.notnull(x) and isinstance(x,str) and len(x)>4 else x)

filtro = dataset['YEAR'].str.len() > 4
dataset.loc[filtro, 'YEAR'] = dataset.loc[filtro, 'YEAR'].apply(
    lambda x: str(x)[:-4] if pd.notnull(x) and isinstance(x, str) and len(x) >= 4 else x
)

# %%
dataset.head()
# Out:
#                                 MOVIES  YEAR  \
# 0                        Blood Red Sky  2021
# 1  Masters of the Universe: Revelation  2021
# 2                     The Walking Dead  2010
# 3                       Rick and Morty  2013
# 4                      Army of Thieves  2021
#
#                                           GENRE  RATING  \
# 0      \r\nAction, Horror, Thriller                 6.1
# 1  \r\nAnimation, Action, Adventure                 5.0
# 2       \r\nDrama, Horror, Thriller                 8.2
# 3  \r\nAnimation, Adventure, Comedy                 9.2
# 4         \r\nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \r\nA woman with a mysterious illness is force...
# 1  \r\nThe war for Eternia begins again in what m...
# 2  \r\nSheriff Deputy Rick Grimes wakes up from a...
# 3  \r\nAn animated series that follows the exploi...
# 4  \r\nA prequel, set before the events of Army o...
#
# ...

# %%
print(dataset['YEAR'].value_counts(normalize=True))
dataset["YEAR"].str.contains("nan").sum()
# Out:
# YEAR
# 2020    0.175167
# 2019    0.139423
# 2018    0.112249
# 2021    0.103156
# 2017    0.087270
#           ...
# 1957    0.000105
# 1972    0.000105
# 1944    0.000105
# 1933    0.000105
# 1938    0.000105
# Name: proportion, Length: 80, dtype: float64
# np.int64(542)

# %%
filtro = dataset.loc[['YEAR'] == "nan"]
dataset = dataset.drop(dataset[filtro].index)

# %%
dataset.loc[dataset['YEAR'] == "", 'YEAR'] = "2020"

# %%
filtro = dataset['YEAR'] != r"[^\d+$]"
filtro
#dataset["YEAR"] = dataset["YEAR"].str.replace(" ","",regex=True)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 9993    True
# 9995    True
# 9996    True
# 9997    True
# 9998    True
# Name: YEAR, Length: 9026, dtype: bool
