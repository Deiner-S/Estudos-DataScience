# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as srn

# %%
df = pd.read_csv("trees.csv")
df.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
plt.hist(df.iloc[:,1], bins=6)
# Out:
# (array([4., 2., 5., 7., 9., 4.]),
#  array([63., 67., 71., 75., 79., 83., 87.]),
#  <BarContainer object of 6 artists>)

# %%
srn.histplot(df.iloc[:,1], kde=True,bins=6,color="Gray")
"""bins = [63, 67, 71, 75, 79, 83, 87]
centros = [(bins[i] + bins[i+1]) / 2 for i in range(len(bins)-1)]
rotulos = [f"{bins[i]}" for i in range(len(bins)-1)]
plt.xticks(centros, rotulos)"""
# Out:
# 'bins = [63, 67, 71, 75, 79, 83, 87]\ncentros = [(bins[i] + bins[i+1]) / 2 for i in range(len(bins)-1)]\nrotulos = [f"{bins[i]}" for i in range(len(bins)-1)]\nplt.xticks(centros, rotulos)'
